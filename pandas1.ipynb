# %%
import pandas as pd

# %% [markdown]
# Creating data - There are two core objects in pandas: the DataFrame and the Series.
#
# DataFrame - A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
pd.DataFrame({'Yes': [78, 21,78], 'No': [131, 2,89]})
# Out:
#    Yes   No
# 0   78  131
# 1   21    2
# 2   78   89

# %% [markdown]
# DataFrame entries are not limited to integers. For instance, here's a DataFrame whose values are strings:

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %% [markdown]
# We use pd.DataFrame() to create DataFrames. The most common way is by using a dictionary, where:
#
# - Keys are the column names (like "Bob" and "Sue")
#
# - Values are lists of data for each column.
#
# By default, the rows are labeled with numbers starting from 0 (like 0, 1, 2, ...). That works sometimes, but often we want to use our own custom row labels.
#
# These row labels are called the Index of the DataFrame. You can set them using the `index` parameter when creating the DataFrame.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# Series - A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# A Series is, in essence, a single column of a DataFrame. So you can assign row labels to the Series the same way as before, using an index parameter. However, a Series does not have a column name, it only has one overall name:

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
methane=pd.read_csv(r"C:\Users\ashid\Desktop\methane_hist_emissions.csv")

# %%
methane
# Out:
#      Country                        Sector  Gas    Unit     2018     2017  \
# 0      China          Total including LUCF  CH4  MTCO2e  1238.95  1239.28
# 1      China          Total excluding LUCF  CH4  MTCO2e  1238.63  1239.13
# 2     Russia          Total including LUCF  CH4  MTCO2e   853.00   852.12
# 3     Russia          Total excluding LUCF  CH4  MTCO2e   849.57   850.17
# 4      China                        Energy  CH4  MTCO2e   739.58   741.73
# ...      ...                           ...  ...     ...      ...      ...
# 1733   Samoa  Land-Use Change and Forestry  CH4  MTCO2e     0.00     0.00
# 1734   Samoa            Fugitive Emissions  CH4  MTCO2e     0.00     0.00
# 1735   Yemen          Industrial Processes  CH4  MTCO2e     0.00     0.00
# 1736   Yemen  Land-Use Change and Forestry  CH4  MTCO2e     0.00     0.00
# 1737  Zambia          Industrial Processes  CH4  MTCO2e     0.00     0.00
#
#          2016     2015     2014     2013  ...    1999    1998    1997    1996  \
# ...

# %%
#We can use the shape attribute to check how large the resulting DataFrame is:
methane.shape
# Out:
# (1738, 33)

# %%
methane.head()
# Out:
#   Country                Sector  Gas    Unit     2018     2017     2016  \
# 0   China  Total including LUCF  CH4  MTCO2e  1238.95  1239.28  1242.43
# 1   China  Total excluding LUCF  CH4  MTCO2e  1238.63  1239.13  1242.15
# 2  Russia  Total including LUCF  CH4  MTCO2e   853.00   852.12   856.00
# 3  Russia  Total excluding LUCF  CH4  MTCO2e   849.57   850.17   852.55
# 4   China                Energy  CH4  MTCO2e   739.58   741.73   743.88
#
#       2015     2014     2013  ...    1999    1998    1997    1996    1995  \
# 0  1237.79  1206.51  1178.21  ...  826.57  814.80  792.55  824.63  798.90
# 1  1237.52  1206.21  1178.02  ...  825.69  813.83  791.73  823.86  798.45
# 2   837.01   833.59   827.06  ...  604.57  606.50  614.99  634.53  643.52
# 3   835.56   830.22   825.64  ...  598.70  597.72  610.38  622.22  639.73
# 4   746.03   723.02   700.01  ...  303.13  289.36  275.59  261.82  248.05
#
#      1994    1993    1992    1991    1990
# 0  774.10  758.01  752.10  743.51  730.78
# ...

# %%
methane=pd.read_csv(r"C:\Users\ashid\Desktop\methane_hist_emissions.csv",index_col=0)
methane.head()
# Out:
#                        Sector  Gas    Unit     2018     2017     2016  \
# Country
# China    Total including LUCF  CH4  MTCO2e  1238.95  1239.28  1242.43
# China    Total excluding LUCF  CH4  MTCO2e  1238.63  1239.13  1242.15
# Russia   Total including LUCF  CH4  MTCO2e   853.00   852.12   856.00
# Russia   Total excluding LUCF  CH4  MTCO2e   849.57   850.17   852.55
# China                  Energy  CH4  MTCO2e   739.58   741.73   743.88
#
#             2015     2014     2013     2012  ...    1999    1998    1997  \
# Country                                      ...
# China    1237.79  1206.51  1178.21  1151.28  ...  826.57  814.80  792.55
# China    1237.52  1206.21  1178.02  1151.10  ...  825.69  813.83  791.73
# Russia    837.01   833.59   827.06   827.98  ...  604.57  606.50  614.99
# Russia    835.56   830.22   825.64   824.27  ...  598.70  597.72  610.38
# China     746.03   723.02   700.01   677.00  ...  303.13  289.36  275.59
#
# ...
